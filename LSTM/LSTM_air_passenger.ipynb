# %% [markdown]
# ### Redes Neurais Artificiais
# ### Professor Ciniro Nametala - IFMG
#
# ## Previsão em séries temporais com Redes Neurais Recorrentes - Células LSTM
#
# Neste trabalho vamos utilizar o *dataset Air Passenger* disponível no [repositório de datasets do Kaggle](https://www.kaggle.com/datasets/rakannimer/air-passengers). O conjunto de dados "Airline Passengers" contém informações mensais sobre o número de passageiros de companhias aéreas ao longo de um período de tempo. Ele geralmente é usado para fins de previsão, onde os modelos de *machine learning* são treinados para prever a demanda futura de passageiros com base nos padrões históricos.
#
# A origem específica desse conjunto de dados remonta à década de 1940 e foi publicado originalmente por Box e Jenkins em seu livro *Time Series Analysis: Forecasting and Control* em 1976. Os dados representam o número mensal de passageiros de uma companhia aérea internacional entre os anos de 1949 e 1960.
#
# Esse conjunto de dados é popular entre os praticantes de *machine learning* devido à sua natureza temporal e à presença de tendências sazonais, tornando-o adequado para a aplicação e teste de algoritmos de previsão. O *dataset* possui 143 valores e duas colunas:
# 1. Mês
# 2. Quantidade de passageiros
#
# Opcionalmente você pode também comentar e descomentar partes do código a seguir para usar a série temporal de preço de fechamento diário da ação do Banco do Brasil (BBAS3) no período entre 02/01/2009 e 04/11/2013. Os valores foram retirados da ferramenta MetaTrader. Neste caso, o *dataset* possui as colunas:
# 1. Data
# 2. Abertura
# 3. Máximo
# 4. Mínimo
# 5. Fechamento
# 6. Volume

# %% [markdown]
# ## 1. Preparação do ambiente

# %% [markdown]
# ### 1.1 Configurações de ambiente

# %%
#funcao para deixar o jupyter com celulas preenchendo toda a tela
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#cria a pasta para armazenar o checkpoint e os modelos treinados
import os
os.makedirs("models", exist_ok=True)

# %% [markdown]
# ### 1.2 Importação de pacotes

# %%
#para exportar o requeriments
import subprocess
import sys

#bibliotecas para trabalhar com dados e graficos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

#bibliotecas do scikit-learn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

#biblioteca para exportacoes e importacoes de arquivos
from joblib import dump, load

#utilitario de GPU para Windows
#from numba import cuda

#biblioteca para implementar uma barra de progresso
import progressbar

#biblioteca para tocar sons
import pygame

#bibliotecas para deep learning
import tensorflow.keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, LSTM, GRU, Bidirectional, Dense

from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

#bibliotecas para plotar graficos do keras
import pydot as pyd
from tensorflow.keras.utils import plot_model, model_to_dot
tensorflow.keras.utils.pydot = pyd
# Out:
# c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.19)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### 1.3 Verificando versões

# %%
import sys
print(f"Python version: {sys.version}")

import numpy as np
print(f"NumPy version: {np.__version__}")

import tensorflow as tf
print(f"TensorFlow version: {tf.__version__}")

import pandas as pd
print(f"Pandas version: {pd.__version__}")

import matplotlib
print(f"Matplotlib version: {matplotlib.__version__}")

import seaborn as sns
print(f"Seaborn version: {sns.__version__}")
# Out:
# Python version: 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# NumPy version: 1.24.3
# TensorFlow version: 2.13.1
# Pandas version: 2.3.3
# Matplotlib version: 3.10.7
# Seaborn version: 0.13.2

# %% [markdown]
# ### 1.4 Checagem de GPU

# %%
# Verificação de GPU (sem warning)
gpus = tf.config.list_physical_devices('GPU')
print(f"TensorFlow encontrou GPUs: {len(gpus) > 0}")
print(f"Dispositivos GPU TensorFlow: {gpus}")
# Out:
# TensorFlow encontrou GPUs: False
# Dispositivos GPU TensorFlow: []

# %% [raw]
# #checa a GPU e limpa ela se usar placas INTEL em Windows
# device = cuda.get_current_device()
# print(device)
# device.reset()
# !nvidia-smi

# %% [markdown]
# ### 1.5 Escolha do dataset

# %%
use_dataset = 'BB' #AP para AirPassenger ou BB para Banco do Brasil
new_model = True   #gerar um novo modelo ou usar um pronto?

# %% [markdown]
# ## 2. Importações de dados

# %% [markdown]
# ### 2.1 Opção a) Air Passenger

# %%
if (use_dataset == 'AP'):
    col_names = ['mes', 'passageiros']

    # importação de dados
    data = pd.read_csv('dataset/airline-passengers.csv', header=0, names=col_names)

    # converte tudo para número
    data['passageiros'] = data['passageiros'].astype("float32")

    x_names = 'passageiros'

    data

# %%
if (use_dataset == 'AP'):
    #ajustando o dataset para treinamento com o keras
    serie = data['passageiros'].values.reshape(-1, 1)

    print(serie.shape)

# %% [markdown]
# ### 2.2 Opção b) Banco do Brasil S.A.

# %%
if (use_dataset == 'BB'):
    col_names = ['data','abertura','maximo','minimo','fechamento','volume']

    # importação de dados
    data = pd.read_csv('dataset/bbas3.csv', header=0, names=col_names, sep=';')

    #remove as colunas nao usadas
    data = data.drop('abertura', axis=1)
    data = data.drop('maximo', axis=1)
    data = data.drop('minimo', axis=1)
    data = data.drop('volume', axis=1)

    # converte tudo para número
    data['fechamento'] = data['fechamento'].astype("float32")

    x_names = 'fechamento'

    #ajustando o dataset para treinamento com o keras
    serie = data['fechamento'].values.reshape(-1, 1)

    print(serie.shape)
# Out:
# (1200, 1)

# %% [markdown]
# ## 3. Configurações do experimento

# %%
#parametros
norm_method = 'asinh' #log, asinh
range_adjust = (0,1)

if (use_dataset == 'AP'):
    #AIR PASSENGERS-------
    size_hist_window = 12 
    size_forw_window = 1
    model_name = 'dnn_air_pass.h5'

if (use_dataset == 'BB'):
    #BANCO DO BRASIL------
    size_hist_window = 20 
    size_forw_window = 10
    model_name = 'dnn_bbas3.h5'

#realizar ajuste dos dados
data_adjust_exec = True

#exportar os datasets tratados
export_frames = True

# %% [markdown]
# ## 4. Análise de dados

# %%
plt.plot(serie)
plt.xlabel("tempo")
plt.ylabel(x_names)
plt.show()

# %% [markdown]
# ### 4.1 Sumarização estatística

# %%
def sumarizacao(serie, column):
    stats = []

    maximum = round(np.max(serie), 2)
    minimum = round(np.min(serie), 2)
    mean = round(np.mean(serie), 2)
    median = round(np.median(serie), 2)
    std = round(np.std(serie), 2)
    stats.append([column, maximum, minimum, mean, median, std])

    headers = ['Coluna', 'Máximo', 'Mínimo', 'Média', 'Mediana', 'Desvio Padrão']

    table = tabulate(stats, headers, tablefmt="pipe")
    print(table)

# %%
sumarizacao(serie, x_names)
# Out:
# | Coluna     |   Máximo |   Mínimo |   Média |   Mediana |   Desvio Padrão |
# |:-----------|---------:|---------:|--------:|----------:|----------------:|
# | fechamento |    24.57 |      7.6 |    17.4 |     18.12 |            3.16 |

# %%
data.boxplot(column=x_names, figsize=(4, 4))
plt.tight_layout()
plt.show()

# %%
data.hist(column=x_names, figsize=(4, 4))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2 Verificando integridade dos dados

# %%
missing_counts = data.isnull().sum()
print("Total de dados faltantes por atributo:")
print(missing_counts)
# Out:
# Total de dados faltantes por atributo:
# data          0
# fechamento    0
# dtype: int64

# %% [markdown]
# ### 4.3 Aplicando normalizacao e escala [0, 1]

# %%
def varianceEstabilization(serie, method):
    if method == 'asinh':
        return np.arcsinh(serie)
    elif method == 'log':
        return np.log(serie)
    else:
        return serie
    
def inverseVarianceEstabilization(serie, method):
    if method == 'asinh':
        return np.sinh(serie)
    elif method == 'log':
        return np.exp(serie)
    else:
        return serie

# %%
#ajuste de dados
if data_adjust_exec:
    serie = varianceEstabilization(serie, norm_method)
    scaler = MinMaxScaler(feature_range=range_adjust)
    serie = scaler.fit_transform(serie)
    
plt.plot(serie)
plt.xlabel("tempo")
plt.ylabel(x_names + " log[0, 1]")
plt.show()

# %%
#desconversao de dados
serie_original = scaler.inverse_transform(serie)
serie_original = inverseVarianceEstabilization(serie_original, norm_method)

plt.plot(serie_original)
plt.xlabel("tempo")
plt.ylabel(x_names + " Quantidade")
plt.show()

# %% [markdown]
# ## 5. Separacao dos conjuntos de dados (treino/validação e teste)

# %%
#separa os conjuntos de treino/validacao e teste
trainval_size = int(len(serie) * 0.70)
test_size = len(serie) - trainval_size
trainval, test = serie[0:trainval_size,:], serie[trainval_size:len(serie),:]

print(trainval.shape)
print(test.shape)
# Out:
# (840, 1)
# (360, 1)

# %% [markdown]
# ### 5.1 Criação das janelas móveis

# %%
#cria os frames com base numa janela historica de dados
def create_frames(serie, back_window_size, forw_window_size):
    x_frames, y_frames = [], []
    
    for i in range(0, len(serie) - back_window_size - 1, forw_window_size):
        x_frames.append(serie[i:(i + back_window_size), 0])
        y_frames.append(serie[(i + back_window_size):(i + back_window_size) + forw_window_size, 0])
        
    return np.array(x_frames), np.array(y_frames)

# %%
#cria os frames
x_trainval, y_trainval = create_frames(trainval, size_hist_window, size_forw_window)
x_test, y_test = create_frames(test, size_hist_window, size_forw_window)

print(x_trainval.shape)
print(y_trainval.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (82, 20)
# (82, 10)
# (34, 20)
# (34, 10)

# %%
serie[0:13]
# Out:
# array([[0.10192943],
#        [0.11764169],
#        [0.16312695],
#        [0.1435225 ],
#        [0.1244266 ],
#        [0.1501069 ],
#        [0.1435225 ],
#        [0.1088388 ],
#        [0.04984331],
#        [0.10192943],
#        [0.0665257 ],
#        [0.06961775],
#        [0.00887799]], dtype=float32)

# %%
x_trainval[0:3]
# Out:
# array([[0.10192943, 0.11764169, 0.16312695, 0.1435225 , 0.1244266 ,
#         0.1501069 , 0.1435225 , 0.1088388 , 0.04984331, 0.10192943,
#         0.0665257 , 0.06961775, 0.00887799, 0.02744555, 0.01547694,
#         0.        , 0.04984331, 0.06445789, 0.08491492, 0.05194616],
#        [0.0665257 , 0.06961775, 0.00887799, 0.02744555, 0.01547694,
#         0.        , 0.04984331, 0.06445789, 0.08491492, 0.05194616,
#         0.05509114, 0.02852535, 0.05404425, 0.04031539, 0.0665257 ,
#         0.07781005, 0.06134701, 0.05194616, 0.06238532, 0.04031539],
#        [0.05509114, 0.02852535, 0.05404425, 0.04031539, 0.0665257 ,
#         0.07781005, 0.06134701, 0.05194616, 0.06238532, 0.04031539,
#         0.0571816 , 0.05194616, 0.02202582, 0.01328301, 0.03068089,
#         0.04031539, 0.05613708, 0.06238532, 0.05299592, 0.00555944]],
#       dtype=float32)

# %%
y_trainval[0:3]
# Out:
# array([[0.05509114, 0.02852535, 0.05404425, 0.04031539, 0.0665257 ,
#         0.07781005, 0.06134701, 0.05194616, 0.06238532, 0.04031539],
#        [0.0571816 , 0.05194616, 0.02202582, 0.01328301, 0.03068089,
#         0.04031539, 0.05613708, 0.06238532, 0.05299592, 0.00555944],
#        [0.01766562, 0.05299592, 0.01984859, 0.03604674, 0.02852535,
#         0.06445789, 0.06961775, 0.07984614, 0.09696031, 0.09496427]],
#       dtype=float32)

# %%
#ajustando para atender aos requisitos de entrada da LSTM: (amostras, timesteps, features)
x_trainval = np.expand_dims(x_trainval, axis=2)
y_trainval = np.expand_dims(y_trainval, axis=2)
x_test = np.expand_dims(x_test, axis=2)
y_test = np.expand_dims(y_test, axis=2)

print(x_trainval.shape)
print(y_trainval.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (82, 20, 1)
# (82, 10, 1)
# (34, 20, 1)
# (34, 10, 1)

# %% [markdown]
# ## 6. Treinamento do modelo

# %% [markdown]
# ### 6.1 Construção do modelo

# %%
#-----------------
#CRIAÇÃO DO MODELO BASEADO EM LSTM
#-----------------

# Configurações de neurônios
units_lstm1 = 16
units_lstm2 = 32
units_lstm3 = 32
units_dense = 16

# Funções de ativação
actfunc_lstm1 = 'tanh'
actfunc_lstm2 = 'tanh'
actfunc_lstm3 = 'tanh'
actfunc_dense = 'tanh'
actfunc_output = 'tanh'

#inicializador
initializer = tensorflow.keras.initializers.LecunNormal(seed=42)

# Criação das entradas de treino+validação
inputs = Input(shape=(x_trainval.shape[1], x_trainval.shape[2]), name="x_train")

# Camada LSTM 1
layer_lstm1 = LSTM(units_lstm1, 
                    activation=actfunc_lstm1, 
                    return_sequences=True,
                    kernel_initializer=initializer)(inputs)

# Camada LSTM 2
layer_lstm2 = LSTM(units_lstm2, 
                    activation=actfunc_lstm2, 
                    return_sequences=True,
                    kernel_initializer=initializer)(layer_lstm1)

# Camada LSTM 3
layer_lstm3 = Bidirectional(LSTM(units_lstm3, 
                                activation=actfunc_lstm3, 
                                return_sequences=False,
                                kernel_initializer=initializer))(layer_lstm2)

# Camada densa final para ajustar o formato da saída
layer_dense = Dense(units_dense, activation=actfunc_dense)(layer_lstm3)

# Camada densa final para ajustar o formato da saída
layer_dense_out = Dense(y_trainval.shape[1], activation=actfunc_output)(layer_dense)

# Criação do modelo
model_trained = Model(inputs=inputs, outputs=layer_dense_out)

# %% [markdown]
# ### 6.2 Inspecionando o modelo

# %% [markdown]
# h = 1
# h - 1 = 16
# entrada no neuronio seguinte = (1 + 16) = 17
# pesos entre a entrada e as celulas = 17 * 16 = 272
# para cada neuronio adiciona o bias = 272 + 16 = 288
# para cada portao = 288 * 4 = 1152

# %%
model_trained.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  x_train (InputLayer)        [(None, 20, 1)]           0
#
#  lstm (LSTM)                 (None, 20, 16)            1152
#
#  lstm_1 (LSTM)               (None, 20, 32)            6272
#
#  bidirectional (Bidirection  (None, 64)                16640
#  al)
#
#  dense (Dense)               (None, 16)                1040
#
#  dense_1 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 25274 (98.73 KB)
# Trainable params: 25274 (98.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_model(model_trained, show_shapes=True, show_layer_names=True, rankdir="TB")  #TB para plotar na vertical

# %% [markdown]
# ### 6.3 Otimização do modelo

# %%
if new_model:
    #com o AirPassenger não usa validacao
    if (use_dataset == 'AP'):
        cp = ModelCheckpoint(
            filepath='models/' + model_name + '_model_trained.weights.h5',
            save_weights_only=True,
            monitor='loss',
            mode='min',
            save_best_only=True
        )
        validation_size = 0.0

        es = EarlyStopping(monitor='loss', mode='min', patience=200)

    #com o Banco do Brasil usa validacao
    if (use_dataset == 'BB'):
        cp = ModelCheckpoint(
            filepath='models/' + model_name + '_model_trained.weights.h5',
            save_weights_only=True,
            monitor='val_loss',
            mode='min',
            save_best_only=True
        )
        validation_size = 0.2

        es = EarlyStopping(monitor='val_loss', mode='min', patience=200)

    
    opt = Adam(learning_rate=0.0001)
    model_trained.compile(optimizer=opt, loss='mean_squared_error')

    history = model_trained.fit(
        x_trainval,
        y_trainval,
        validation_split=validation_size,
        epochs=500,
        verbose=1,
        callbacks=[cp, es],
        batch_size=1,
        shuffle=False
    )

    np.save('models/' + model_name + '_history_model.npy', history.history)
    model_trained.load_weights('models/' + model_name + '_model_trained.weights.h5')
    model_trained.save('models/' + model_name + '.keras')
else:
    model_trained = load_model('models/' + model_name + '.keras')
# Out:
# Epoch 1/500
# 65/65 [==============================] - 5s 24ms/step - loss: 0.2990 - val_loss: 0.1576
# Epoch 2/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0960 - val_loss: 0.0465
# Epoch 3/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0414 - val_loss: 0.0216
# Epoch 4/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0277 - val_loss: 0.0135
# Epoch 5/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0216 - val_loss: 0.0098
# Epoch 6/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0178 - val_loss: 0.0080
# Epoch 7/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0149 - val_loss: 0.0070
# Epoch 8/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0127 - val_loss: 0.0064
# Epoch 9/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0107 - val_loss: 0.0061
# Epoch 10/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0089 - val_loss: 0.0059
# Epoch 11/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 12/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 13/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 14/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0051 - val_loss: 0.0058
# Epoch 15/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0046 - val_loss: 0.0059
# Epoch 16/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0043 - val_loss: 0.0060
# Epoch 17/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0041 - val_loss: 0.0060
# Epoch 18/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0039 - val_loss: 0.0061
# Epoch 19/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0062
# Epoch 20/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0062
# Epoch 21/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 22/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 0.0063
# Epoch 23/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0063
# Epoch 24/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0063
# Epoch 25/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 26/500
# 65/65 [==============================] - 1s 12ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 27/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 28/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 29/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 30/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 31/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 32/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 33/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0062
# Epoch 34/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0062
# Epoch 35/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0062
# Epoch 36/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0062
# Epoch 37/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0062
# Epoch 38/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0031 - val_loss: 0.0062
# Epoch 39/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0061
# Epoch 40/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0061
# Epoch 41/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0061
# Epoch 42/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 0.0061
# Epoch 43/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 44/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 45/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 46/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0060
# Epoch 47/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0059
# Epoch 48/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0059
# Epoch 49/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0029 - val_loss: 0.0059
# Epoch 50/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 51/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 52/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 0.0058
# Epoch 53/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0028 - val_loss: 0.0057
# Epoch 54/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0028 - val_loss: 0.0057
# Epoch 55/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 0.0057
# Epoch 56/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 0.0056
# Epoch 57/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 0.0056
# Epoch 58/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0056
# Epoch 59/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0055
# Epoch 60/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0055
# Epoch 61/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0055
# Epoch 62/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0054
# Epoch 63/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0054
# Epoch 64/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0054
# Epoch 65/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 0.0054
# Epoch 66/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0053
# Epoch 67/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0053
# Epoch 68/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0026 - val_loss: 0.0053
# Epoch 69/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0052
# Epoch 70/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0052
# Epoch 71/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0052
# Epoch 72/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0052
# Epoch 73/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0051
# Epoch 74/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0025 - val_loss: 0.0051
# Epoch 75/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0051
# Epoch 76/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0051
# Epoch 77/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0051
# Epoch 78/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 79/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 80/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 81/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 82/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 83/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 84/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0049
# Epoch 85/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 86/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 87/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 88/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 89/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 90/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 91/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 92/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 93/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 94/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 95/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 96/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0022 - val_loss: 0.0048
# Epoch 97/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0048
# Epoch 98/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 99/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 100/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 101/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 102/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 103/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 104/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 105/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 106/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 107/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 108/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 109/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 110/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 111/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 112/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 113/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 114/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 115/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 116/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 117/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 118/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 119/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 120/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 121/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 122/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 123/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 124/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 125/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 126/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 127/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0044
# Epoch 128/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 129/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 130/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 131/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 132/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 133/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0044
# Epoch 134/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 135/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 136/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 137/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 138/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 139/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 140/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 141/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 142/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 143/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 144/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 145/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 146/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 147/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 148/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 149/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 150/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 151/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 152/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 153/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 154/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 155/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 156/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 157/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 158/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 159/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 160/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 161/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 162/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 163/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 164/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 165/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 166/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 167/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 168/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 169/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 170/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 171/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 172/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 173/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 174/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 175/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 176/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 177/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 178/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 179/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 180/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 181/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 182/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 183/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 184/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 185/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 186/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 187/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 188/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 189/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 190/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 191/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 192/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 193/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 194/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 195/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 196/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 197/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 198/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 199/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 200/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 201/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 202/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 203/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 204/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 205/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 206/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 207/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 208/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 209/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 210/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 211/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 212/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 213/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 214/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 215/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 216/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 217/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 218/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 219/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 220/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 221/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 222/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 223/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 224/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 225/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 226/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 227/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 228/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 229/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 230/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 231/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 232/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 233/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 234/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 235/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 236/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 237/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 238/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 239/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 240/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 241/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 242/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 243/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 244/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 245/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 246/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 247/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 248/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 249/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 250/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 251/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 252/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 253/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 254/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 255/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 256/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 257/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 258/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 259/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 260/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 261/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 262/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 263/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 264/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 265/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 266/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 267/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 268/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 269/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0037
# Epoch 270/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 271/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 272/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 273/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 274/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 275/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 276/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 277/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 278/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 279/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 280/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 281/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 282/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 283/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 284/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 285/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 286/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 287/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 288/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 289/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 290/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 291/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 292/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 293/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 294/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 295/500
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 296/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 297/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 298/500
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 299/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 300/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 301/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 302/500
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 303/500
# 50/65 [======================>.......] - ETA: 0s - loss: 0.0016
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 32
#      29 opt = Adam(learning_rate=0.0001)
#      30 model_trained.compile(optimizer=opt, loss='mean_squared_error')
# ---> 32 history = model_trained.fit(
#      33     x_trainval,
#      34     y_trainval,
#      35     validation_split=validation_size,
#      36     epochs=500,
#      37     verbose=1,
#      38     callbacks=[cp, es],
#      39     batch_size=1,
#      40     shuffle=False
#      41 )
#      43 np.save('models/' + model_name + '_history_model.npy', history.history)
#      44 model_trained.load_weights('models/' + model_name + '_model_trained.weights.h5')
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File c:\Users\rocha\anaconda3\envs\tf310\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 6.4 Avaliação do modelo com curva de convergência
#
# Descomente este código se você estiver realizando testes com conjunto de validação para ver a curva de convergência

# %%
history=np.load('models/' + model_name + '_history_model.npy', allow_pickle='TRUE').item()

sns.set(rc={'figure.figsize':(12, 6)})
sns.set_style('whitegrid')
sns.set_context('paper')

train_metric = history['loss']

if (use_dataset == 'BB'):
    valid_metric = history['val_loss']
    
name_metric = 'mse'

fig = plt.figure()

plt.plot(train_metric, label='TREINO')

if (use_dataset == 'BB'):
    plt.plot(valid_metric, label='VALIDAÇÃO')

plt.ylabel(name_metric.upper())
plt.xlabel('epoch')

if (use_dataset == 'BB'):
    plt.title('Treino vs. Validação usando: ' + name_metric.upper())
else:
    plt.title('Treino usando: ' + name_metric.upper())
    
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)

plt.show()

# %% [markdown]
# ## 7. Testando as previsões

# %% [markdown]
# ### 7.1 Gerando as previsões com o modelo treinado

# %%
test[0:13]
# Out:
# array([[0.68643427],
#        [0.7830987 ],
#        [0.8373513 ],
#        [0.83975077],
#        [0.75872636],
#        [0.67369056],
#        [0.601557  ],
#        [0.6556792 ],
#        [0.6622958 ],
#        [0.6248944 ],
#        [0.69735193],
#        [0.6752994 ],
#        [0.69889426]], dtype=float32)

# %%
x_test[0:1]
# Out:
# array([[[0.68643427],
#         [0.7830987 ],
#         [0.8373513 ],
#         [0.83975077],
#         [0.75872636],
#         [0.67369056],
#         [0.601557  ],
#         [0.6556792 ],
#         [0.6622958 ],
#         [0.6248944 ],
#         [0.69735193],
#         [0.6752994 ]]], dtype=float32)

# %%
y_test[0:1]
# Out:
# array([[[0.69889426]]], dtype=float32)

# %%
if (use_dataset == 'AP'):
    #AIR PASSENGER
    #pega os dados reais e volta para a escala original - air passenger
    y_true = scaler.inverse_transform(y_test.reshape(y_test.shape[0],1))
    y_true = inverseVarianceEstabilization(y_true, norm_method).flatten()

# %%
if (use_dataset == 'BB'):
    #BANCO DO BRASIL
    #pega os dados reais e volta para a escala original - bbas3
    y_true = scaler.inverse_transform(y_test.reshape(y_test.flatten().shape[0],1))
    y_true = inverseVarianceEstabilization(y_true, norm_method).flatten()

# %%
y_true
# Out:
# array([363.00006, 435.00003, 490.9999 , 504.99994, 403.9999 , 358.99994,
#        309.9999 , 336.99997, 360.00003, 341.9999 , 406.00006, 395.99997,
#        419.99997, 471.99997, 548.0001 , 559.00006, 463.     , 407.00006,
#        362.0001 , 405.     , 417.00003, 390.9999 , 419.     , 460.9999 ,
#        471.99997, 535.     , 621.9998 , 605.9998 , 508.0001 , 460.9999 ,
#        390.     ], dtype=float32)

# %%
y_true.shape
# Out:
# (31,)

# %%
#realiza as previsoes do modelo treinado no conjunto de testes e volta para a escala original
y_hat = model_trained.predict(x_test)
# Out:
# 1/1 [==============================] - 1s 826ms/step

# %%
#pega os dados previstos e coloca na escala original
y_hat = scaler.inverse_transform(y_hat)
y_hat = inverseVarianceEstabilization(y_hat, norm_method).flatten()
y_hat.shape
# Out:
# (31,)

# %% [markdown]
# ### 7.2 Avaliando as previsões

# %%
def mape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def printRegressionMetrics(y_true, y_pred):
    
    MAPE = mape(y_true, y_pred)
    R2 = metrics.r2_score(y_true, y_pred)
    
    print('MAPE:')
    print(MAPE)
    print('R2:')
    print(R2)

# %%
printRegressionMetrics(y_true, y_hat)
# Out:
# MAPE:
# 8.438333123922348
# R2:
# 0.47292447090148926

# %%
if (use_dataset == 'AP'):
    #AIR PASSENGER
    #pega os valores reais anteriores ao ponto de previsao - air passenger
    y_true_trainval = y_trainval.flatten().reshape(len(y_trainval),1)
    y_true_trainval = scaler.inverse_transform(y_true_trainval)
    y_true_trainval = inverseVarianceEstabilization(y_true_trainval, norm_method).flatten()

# %%
if (use_dataset == 'BB'):
    #BANCO DO BRASIL
    #pega os valores reais anteriores ao ponto de previsao - bbas3
    y_true_trainval = y_trainval.flatten().reshape(len(y_trainval.flatten()),1)
    y_true_trainval = scaler.inverse_transform(y_true_trainval)
    y_true_trainval = inverseVarianceEstabilization(y_true_trainval, norm_method).flatten()

# %%
y_true_trainval.shape
# Out:
# (87,)

# %%
#cria um data table com os valores reais e preditos
df_forecast = pd.DataFrame()
df_forecast['y_true'] = np.hstack((y_true_trainval, y_true))
df_forecast['y_hat'] = np.hstack((y_true_trainval, y_hat))

df_forecast.shape
# Out:
# (118, 2)

# %%
sns.set(rc={'figure.figsize':(15, 4)})
sns.set_style('whitegrid')
sns.set_context('paper')

ax = df_forecast.plot(x_compat=True, style='-')
ax.set_xlabel("Data")
ax.legend(["Real", "Predito"])

plt.grid(True)

plt.show()

plt.close()

sns.set(rc={'figure.figsize':(12, 6)})
sns.set_style('whitegrid')
sns.set_context('paper')

plt.figure(figsize=(15, 4))
plt.hist(y_true, bins=10, color='orange', alpha=0.5, label='Real')
plt.hist(y_hat, bins=10, color='green', alpha=0.5, label='Predito')
plt.legend()

plt.show()

plt.close()

# %%
#toca um som para avisar que terminou de executar
pygame.mixer.init()
arquivo_mp3 = 'support_files/mario_coin.mp3'
pygame.mixer.music.load(arquivo_mp3)
pygame.mixer.music.play()

while pygame.mixer.music.get_busy():
    continue
    
print('Sucesso!')
# Out:
# Sucesso!
